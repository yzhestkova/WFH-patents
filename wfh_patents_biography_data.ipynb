# %% [markdown]
# ### This code downloads XML bulks of patent BIBLIOGRPAHIC data from USPTO, parses it into a dataframe and creates a flag for patents supporting working-from-home technologies.

# %%
#Uploading necessary packages
import pandas as pd
import pandas_read_xml as pdx
import numpy as np
import re
import os

# %%
#Specifying the directory where all weekly txt raw patent files are stored
for j in range(2005,2021):
    print("Processing year {}".format(j))
    
    directory = '/Users/yulia_zhestkova/Patent parsing/'+str(j)+'/'
    os.chdir('/Users/yulia_zhestkova/Patent parsing/'+str(j)+'/')

#Going through all the txt files and splitting them into individual patent txt pieces
    i=0
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            file=open(file=filename, mode='r')
            file_content_raw=file.read()
            file.close()
            text1=re.compile("<\?xml version=\"1\.0\" encoding\=\"UTF\-8\"\?>") #identifier of a new patent in XML
            file_content=text1.split(file_content_raw)
            while '' in file_content:
                file_content.remove('')
    
            print("Processing file {}".format(filename)) 

#Formatting the list of individual patent documents into a pandas dataframe (table)
            df=pd.DataFrame(file_content, columns=['application_full'])
#Getting rid of formating tags
            df['application_full'].replace(to_replace=r'\n', value='', regex=True, inplace=True)
            df['application_full'].replace(to_replace=r'\"', value='', regex=True, inplace=True)
#Extracting the part of the file with the bibliographic information
            df['date_published']=df['application_full'].apply(lambda x: re.search(r'date-publ=(.*)><us-bibliographic-data-application', x).group(1))
            df['info']=df['application_full'].apply(lambda x: re.search(r'<application-reference(.*)</application-reference>', x).group(1))
#Extracting title and abstract
            df['title']=df['application_full'].apply(lambda x: "" if re.search(r'<invention-title(.*)</invention-title>', x)==None else re.search(r'<invention-title(.*)</invention-title>', x).group(1))
            df['abstract']=df['application_full'].apply(lambda x: "" if re.search('<abstract(.*)</abstract>', x)==None else re.search('<abstract(.*)</abstract>', x).group(1))
#Extracting assignee and CPC class information
            df['assignee']=df['application_full'].apply(lambda x: "" if re.search('<orgname(.*)</orgname>', x)==None else re.search('<orgname(.*)</orgname>', x).group(1))
            df['main_class']=df['application_full'].apply(lambda x: "" if re.search('<classifications-cpc><main-cpc><classification-cpc>(.*)</classification-cpc></main-cpc>', x)==None else re.search('<classifications-cpc><main-cpc><classification-cpc>(.*)</classification-cpc></main-cpc>', x).group(1))
            df=df.drop(['application_full'], axis=1)
#Cleaning out and identyfing exact parts with application id, application filing date, country, title and abstract
            df['app_id']=df['info'].apply(lambda x: "" if re.search(r'<doc-number>(.*)</doc-number>', x)==None else re.search(r'<doc-number>(.*)</doc-number>', x).group(1))
            df['date']=df['info'].apply(lambda x: "" if re.search(r'<date>(.*)</date>', x)==None else re.search(r'<date>(.*)</date>', x).group(1))
            df['country']=df['info'].apply(lambda x: "" if re.search(r'<country>(.*)</country>', x)==None else re.search(r'<country>(.*)</country>', x).group(1))
            df['title']=df['title'].apply(lambda x: "" if re.search(r'id=\w{5,6}>(.*)', x)==None else re.search(r'id=\w{5,6}>(.*)', x).group(1))
            df['abstract']=df['abstract'].apply(lambda x: "" if re.search(r'id=abstract><p id=p-0001 num=0000>(.*)</p>', x)==None else re.search(r'id=abstract><p id=p-0001 num=0000>(.*)</p>', x).group(1))
            df=df[['title', 'abstract', 'assignee', 'main_class', 'app_id', 'date','country', 'date_published']]
#Cleaning XML class tree to extract section, class, subclass, group, subgroup        
            df['section']=df['main_class'].apply(lambda x: "" if re.search(r'<section>(.*)</section>', x)==None else re.search(r'<section>(.*)</section>', x).group(1))
            df['class']=df['main_class'].apply(lambda x: "" if re.search(r'<class>(.*)</class>', x)==None else re.search(r'<class>(.*)</class>', x).group(1))
            df['subclass']=df['main_class'].apply(lambda x: "" if re.search(r'<subclass>(.*)</subclass>', x)==None else re.search(r'<subclass>(.*)</subclass>', x).group(1))
            df['group']=df['main_class'].apply(lambda x: "" if re.search(r'<main-group>(.*)</main-group>', x)==None else re.search(r'<main-group>(.*)</main-group>', x).group(1))
            df['subgroup']=df['main_class'].apply(lambda x: "" if re.search(r'<subgroup>(.*)</subgroup>', x)==None else re.search(r'<subgroup>(.*)</subgroup>', x).group(1))
            df=df.drop(['main_class'], axis=1)
#Cleaning up assignee name a bit -- still extremely noisy with many strange symbols. Not ready for use as is and require more cleaning if needed
            df['assignee_clean']=df['assignee'].apply(lambda x: "" if re.search(r'>(.*)</orgname>', x)==None else re.search(r'>(.*)</orgname>', x).group(1))
            df['assignee_clean']=np.where(df['assignee_clean']!="", df['assignee_clean'], df['assignee'])
            df['assignee_clean'].replace(to_replace=r'>', value='', regex=True, inplace=True)
            df['assignee_clean_final']=df['assignee_clean'].apply(lambda x: "" if re.search('(.*?)</orgname', x)==None else re.search('(.*?)</orgname', x).group(1))
            df['assignee_clean_final']=np.where(df['assignee_clean_final']=="", df['assignee_clean'], df['assignee_clean_final'])
            df=df.drop(['assignee', 'assignee_clean'], axis=1)
#First 2 digits of application id is series code, other 6 numbers are series id.
            df['series_code']=df['app_id'].astype(str).str[:2]
            df['series_id']=df['app_id'].astype(str).str[2:]
#Cleaning up the text of the patent that we are going to work with (title+abstract)
            df['text']=df['abstract'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
            df['text']=df['title']+" "+df['abstract']
            df['text']=df['text'].str.lower() #all lower case
            df['text']=df['text'].apply(lambda x: re.sub(r'[^A-Za-z ]+', '', x)) #leave only letters
            df=df.rename(columns={'assignee_clean_final':'assignee'})
#Cleaning up assignee names a bit:
            df['assignee']=df['assignee'].str.lower()
            df['assignee'] = df['assignee'].str.replace('&amp',' ')
            df['assignee'] = df['assignee'].str.replace('&apos',' ')
            df['assignee'] = df['assignee'].str.replace('&#x26',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf8',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc4',' ')
            df['assignee'] = df['assignee'].str.replace('&#xdc',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc9',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe9',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe0',' ')
            df['assignee'] = df['assignee'].str.replace('&#xcd',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc0',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc1',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc8',' ')  
            df['assignee'] = df['assignee'].str.replace('&#xd6',' ')           
            df['assignee'] = df['assignee'].str.replace('&#xe7',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xda',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd4',' ')  
            df['assignee'] = df['assignee'].str.replace('&#xed',' ')
            df['assignee'] = df['assignee'].str.replace('&#xfc',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc7',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe8',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe4',' ')
            df['assignee'] = df['assignee'].str.replace('&#xed',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf2',' ')          
            df['assignee'] = df['assignee'].str.replace(' ltd',' ')
            df['assignee'] = df['assignee'].str.replace(' incorporated',' ')
            df['assignee'] = df['assignee'].str.replace(' inc.',' ')
            df['assignee'] = df['assignee'].str.replace(' gmbh',' ')
            df['assignee'] = df['assignee'].str.replace(' ag.',' ')
            df['assignee'] = df['assignee'].str.replace(' kg.',' ')
            df['assignee'] = df['assignee'].str.replace(' llc',' ')
            df['assignee'] = df['assignee'].str.replace(' limited',' ')
            df['assignee'] = df['assignee'].str.replace('s.p.a.',' ')
            df['assignee'] = df['assignee'].str.replace(' corporation',' ')
            df['assignee'] = df['assignee'].str.replace(' group',' ')
            df['assignee'] = df['assignee'].str.replace(' corp.',' ')
            df['assignee'] = df['assignee'].str.replace(' co.',' ')
            df['assignee'] = df['assignee'].str.replace('co. kg',' ')
            df['assignee'] = df['assignee'].str.replace('(publ)',' ')
            df['assignee'] = df['assignee'].str.replace('s.a.s.',' ')
            df['assignee'] = df['assignee'].str.replace('s.r.o.',' ')       
            df['assignee'] = df['assignee'].str.replace('s.r.l.',' ')
            df['assignee'] = df['assignee'].str.replace('k.k.',' ')
            df['assignee'] = df['assignee'].str.replace('b.v.',' ')
            df['assignee'] = df['assignee'].str.replace('s.a.r.l.',' ')
            df['assignee'] = df['assignee'].str.replace('a.s.',' ')
            df['assignee'] = df['assignee'].str.replace('v.v.i.',' ')
            df['assignee'] = df['assignee'].str.replace(' company',' ')
            df=df[['date_published','text', 'title', 'assignee', 'date', 'country', 'section', 'class', 'subclass', 'group', 'series_code', 'series_id', 'app_id']]

#Combining all files for one year in one csv file
            if i==0:
                master_df=df
            else:
                master_df=master_df.append(df, ignore_index=True)
    
            i=i+1
            del df
        
    master_df.to_csv (r'complete'+str(j)+'.csv', index = None)

del master_df
# Out:
# Processing year 2005
# Processing file ipab20050407.txt
# Processing file ipab20050203.txt
# Processing file ipab20050217.txt
# Processing file ipab20050414.txt
# Processing file ipab20050428.txt
# Processing file ipab20050616.txt
# Processing file ipab20050602.txt
# Processing file ipab20050825.txt
# Processing file ipab20051124.txt
# Processing file ipab20050818.txt
# Processing file ipab20050210.txt
# Processing file ipab20050303.txt
# Processing file ipab20050317.txt
# Processing file ipab20050707.txt
# Processing file ipab20050908.txt
# Processing file ipab20050505.txt
# Processing file ipab20051222.txt
# Processing file ipab20051020.txt
# Processing file ipab20051208.txt
# Processing file ipab20050512.txt
# Processing file ipab20050922.txt
# Processing file ipab20051027.txt
# Processing file ipab20050113.txt
# Processing file ipab20050728.txt
# Processing file ipab20050714.txt
# Processing file ipab20050106.txt
# Processing file ipab20050310.txt
# Processing file ipab20050120.txt
# Processing file ipab20050915.txt
# Processing file ipab20050901.txt
# Processing file ipab20050929.txt
# Processing file ipab20050519.txt
# Processing file ipab20051215.txt
# Processing file ipab20051201.txt
# Processing file ipab20051229.txt
# Processing file ipab20050526.txt
# Processing file ipab20050324.txt
# Processing file ipab20051006.txt
# Processing file ipab20050721.txt
# Processing file ipab20050127.txt
# Processing file ipab20051013.txt
# Processing file ipab20050331.txt
# Processing file ipab20051117.txt
# Processing file ipab20051103.txt
# Processing file ipab20050630.txt
# Processing file ipab20050421.txt
# Processing file ipab20050623.txt
# Processing file ipab20050804.txt
# Processing file ipab20051110.txt
# Processing file ipab20050811.txt
# Processing file ipab20050224.txt
# Processing file ipab20050609.txt
# Processing year 2006
# Processing file ipab20061221.txt
# Processing file ipab20060511.txt
# Processing file ipab20060713.txt
# Processing file ipab20060316.txt
# Processing file ipab20060302.txt
# Processing file ipab20060706.txt
# Processing file ipab20060921.txt
# Processing file ipab20060504.txt
# Processing file ipab20061019.txt
# Processing file ipab20060105.txt
# Processing file ipab20061026.txt
# Processing file ipab20060112.txt
# Processing file ipab20061109.txt
# Processing file ipab20060216.txt
# Processing file ipab20060202.txt
# Processing file ipab20060406.txt
# Processing file ipab20060413.txt
# Processing file ipab20061123.txt
# Processing file ipab20060601.txt
# Processing file ipab20060615.txt
# Processing file ipab20060629.txt
# Processing file ipab20061130.txt
# Processing file ipab20060831.txt
# Processing file ipab20060824.txt
# Processing file ipab20060223.txt
# Processing file ipab20060209.txt
# Processing file ipab20060427.txt
# Processing file ipab20060817.txt
# Processing file ipab20060803.txt
# Processing file ipab20061102.txt
# Processing file ipab20061116.txt
# Processing file ipab20060608.txt
# Processing file ipab20060810.txt
# Processing file ipab20060420.txt
# Processing file ipab20060622.txt
# Processing file ipab20060309.txt
# Processing file ipab20061228.txt
# Processing file ipab20061214.txt
# Processing file ipab20060518.txt
# Processing file ipab20060323.txt
# Processing file ipab20060727.txt
# Processing file ipab20060928.txt
# Processing file ipab20060914.txt
# Processing file ipab20060525.txt
# Processing file ipab20061207.txt
# Processing file ipab20060119.txt
# Processing file ipab20061005.txt
# Processing file ipab20060907.txt
# Processing file ipab20060720.txt
# Processing file ipab20060126.txt
# Processing file ipab20060330.txt
# Processing file ipab20061012.txt
# Processing year 2007
# Processing file ipab20070517.txt
# Processing file ipab20070503.txt
# Processing file ipab20070927.txt
# Processing file ipab20071018.txt
# Processing file ipab20070104.txt
# Processing file ipab20070111.txt
# Processing file ipab20071227.txt
# Processing file ipab20071025.txt
# Processing file ipab20070920.txt
# Processing file ipab20070510.txt
# Processing file ipab20070712.txt
# Processing file ipab20071220.txt
# Processing file ipab20070329.txt
# Processing file ipab20070315.txt
# Processing file ipab20070301.txt
# Processing file ipab20070705.txt
# Processing file ipab20070830.txt
# Processing file ipab20070614.txt
# Processing file ipab20070628.txt
# Processing file ipab20071122.txt
# Processing file ipab20070412.txt
# Processing file ipab20070823.txt
# Processing file ipab20070215.txt
# Processing file ipab20070201.txt
# Processing file ipab20070405.txt
# Processing file ipab20070607.txt
# Processing file ipab20070809.txt
# Processing file ipab20071108.txt
# Processing file ipab20070621.txt
# Processing file ipab20070816.txt
# Processing file ipab20070802.txt
# Processing file ipab20070426.txt
# Processing file ipab20070208.txt
# Processing file ipab20070222.txt
# Processing file ipab20070419.txt
# Processing file ipab20071101.txt
# Processing file ipab20071115.txt
# Processing file ipab20071129.txt
# Processing file ipab20070913.txt
# Processing file ipab20070906.txt
# Processing file ipab20071011.txt
# Processing file ipab20071213.txt
# Processing file ipab20070125.txt
# Processing file ipab20071206.txt
# Processing file ipab20070118.txt
# Processing file ipab20071004.txt
# Processing file ipab20070726.txt
# Processing file ipab20070524.txt
# Processing file ipab20070322.txt
# Processing file ipab20070531.txt
# Processing file ipab20070719.txt
# Processing file ipab20070308.txt
# Processing year 2008
# Processing file ipab20080814.txt
# Processing file ipab20080828.txt
# Processing file ipab20080626.txt
# Processing file ipab20080424.txt
# Processing file ipab20080221.txt
# Processing file ipab20080619.txt
# Processing file ipab20081113.txt
# Processing file ipab20081106.txt
# Processing file ipab20080807.txt
# Processing file ipab20081016.txt
# Processing file ipab20081002.txt
# Processing file ipab20080320.txt
# Processing file ipab20080724.txt
# Processing file ipab20080731.txt
# Processing file ipab20080124.txt
# Processing file ipab20080911.txt
# Processing file ipab20080508.txt
# Processing file ipab20080904.txt
# Processing file ipab20080131.txt
# Processing file ipab20080327.txt
# Processing file ipab20081211.txt
# Processing file ipab20080522.txt
# Processing file ipab20081204.txt
# Processing file ipab20081023.txt
# Processing file ipab20080117.txt
# Processing file ipab20080103.txt
# Processing file ipab20080710.txt
# Processing file ipab20081009.txt
# Processing file ipab20080313.txt
# Processing file ipab20080717.txt
# Processing file ipab20080703.txt
# Processing file ipab20080918.txt
# Processing file ipab20080515.txt
# Processing file ipab20080501.txt
# Processing file ipab20080529.txt
# Processing file ipab20080925.txt
# Processing file ipab20080110.txt
# Processing file ipab20081030.txt
# Processing file ipab20080306.txt
# Processing file ipab20081218.txt
# Processing file ipab20081225.txt
# Processing file ipab20080410.txt
# Processing file ipab20080612.txt
# Processing file ipab20080821.txt
# Processing file ipab20081120.txt
# Processing file ipab20080605.txt
# Processing file ipab20080214.txt
# Processing file ipab20080228.txt
# Processing file ipab20081127.txt
# Processing file ipab20080417.txt
# Processing file ipab20080403.txt
# Processing file ipab20080207.txt
# Processing year 2009
# Processing file ipab20090226.txt
# Processing file ipab20091105.txt
# Processing file ipab20090409.txt
# Processing file ipab20090806.txt
# Processing file ipab20090423.txt
# Processing file ipab20090219.txt
# Processing file ipab20091112.txt
# Processing file ipab20090813.txt
# Processing file ipab20090618.txt
# Processing file ipab20090625.txt
# Processing file ipab20090430.txt
# Processing file ipab20090319.txt
# Processing file ipab20090709.txt
# Processing file ipab20091210.txt
# Processing file ipab20090326.txt
# Processing file ipab20090910.txt
# Processing file ipab20090723.txt
# Processing file ipab20090521.txt
# Processing file ipab20091217.txt
# Processing file ipab20091203.txt
# Processing file ipab20091029.txt
# Processing file ipab20091015.txt
# Processing file ipab20091001.txt
# Processing file ipab20090108.txt
# Processing file ipab20090122.txt
# Processing file ipab20090730.txt
# Processing file ipab20090917.txt
# Processing file ipab20090903.txt
# Processing file ipab20091224.txt
# Processing file ipab20090305.txt
# Processing file ipab20091231.txt
# Processing file ipab20090924.txt
# Processing file ipab20090716.txt
# Processing file ipab20090702.txt
# Processing file ipab20090514.txt
# Processing file ipab20090528.txt
# Processing file ipab20090312.txt
# Processing file ipab20091008.txt
# Processing file ipab20090129.txt
# Processing file ipab20090101.txt
# Processing file ipab20090115.txt
# Processing file ipab20090507.txt
# Processing file ipab20091022.txt
# Processing file ipab20091119.txt
# Processing file ipab20090212.txt
# Processing file ipab20090827.txt
# Processing file ipab20090416.txt
# Processing file ipab20090402.txt
# Processing file ipab20091126.txt
# Processing file ipab20090205.txt
# Processing file ipab20090611.txt
# Processing file ipab20090604.txt
# Processing file ipab20090820.txt
# Processing year 2010
# Processing file ipab20100225.txt
# Processing file ipab20100812.txt
# Processing file ipab20100422.txt
# Processing file ipab20100218.txt
# Processing file ipab20101104.txt
# Processing file ipab20100805.txt
# Processing file ipab20100408.txt
# Processing file ipab20101111.txt
# Processing file ipab20100624.txt
# Processing file ipab20100520.txt
# Processing file ipab20100722.txt
# Processing file ipab20101007.txt
# Processing file ipab20100325.txt
# Processing file ipab20100318.txt
# Processing file ipab20100708.txt
# Processing file ipab20100902.txt
# Processing file ipab20100916.txt
# Processing file ipab20100527.txt
# Processing file ipab20100121.txt
# Processing file ipab20101014.txt
# Processing file ipab20101028.txt
# Processing file ipab20101202.txt
# Processing file ipab20101216.txt
# Processing file ipab20100930.txt
# Processing file ipab20101230.txt
# Processing file ipab20100304.txt
# Processing file ipab20100311.txt
# Processing file ipab20100107.txt
# Processing file ipab20100701.txt
# Processing file ipab20100715.txt
# Processing file ipab20100729.txt
# Processing file ipab20100513.txt
# Processing file ipab20101209.txt
# Processing file ipab20100923.txt
# Processing file ipab20100506.txt
# Processing file ipab20100909.txt
# Processing file ipab20100114.txt
# Processing file ipab20100128.txt
# Processing file ipab20101021.txt
# Processing file ipab20101223.txt
# Processing file ipab20100204.txt
# Processing file ipab20100826.txt
# Processing file ipab20100211.txt
# Processing file ipab20101125.txt
# Processing file ipab20100603.txt
# Processing file ipab20100617.txt
# Processing file ipab20100429.txt
# Processing file ipab20100401.txt
# Processing file ipab20100415.txt
# Processing file ipab20100819.txt
# Processing file ipab20101118.txt
# Processing file ipab20100610.txt
# Processing year 2011
# Processing file ipab20110630.txt
# Processing file ipab20111103.txt
# Processing file ipab20111117.txt
# Processing file ipab20111110.txt
# Processing file ipab20110811.txt
# Processing file ipab20110804.txt
# Processing file ipab20110623.txt
# Processing file ipab20110421.txt
# Processing file ipab20110609.txt
# Processing file ipab20110224.txt
# Processing file ipab20110519.txt
# Processing file ipab20110120.txt
# Processing file ipab20110929.txt
# Processing file ipab20110901.txt
# Processing file ipab20110915.txt
# Processing file ipab20110526.txt
# Processing file ipab20111229.txt
# Processing file ipab20111201.txt
# Processing file ipab20111215.txt
# Processing file ipab20110721.txt
# Processing file ipab20110331.txt
# Processing file ipab20111013.txt
# Processing file ipab20110127.txt
# Processing file ipab20111006.txt
# Processing file ipab20110324.txt
# Processing file ipab20111020.txt
# Processing file ipab20111222.txt
# Processing file ipab20110317.txt
# Processing file ipab20110303.txt
# Processing file ipab20110505.txt
# Processing file ipab20110908.txt
# Processing file ipab20110707.txt
# Processing file ipab20110922.txt
# Processing file ipab20111208.txt
# Processing file ipab20110512.txt
# Processing file ipab20110714.txt
# Processing file ipab20110728.txt
# Processing file ipab20110310.txt
# Processing file ipab20110106.txt
# Processing file ipab20110113.txt
# Processing file ipab20111027.txt
# Processing file ipab20110407.txt
# Processing file ipab20110217.txt
# Processing file ipab20110203.txt
# Processing file ipab20110818.txt
# Processing file ipab20110825.txt
# Processing file ipab20110602.txt
# Processing file ipab20110616.txt
# Processing file ipab20110428.txt
# Processing file ipab20110414.txt
# Processing file ipab20111124.txt
# Processing file ipab20110210.txt
# Processing year 2012
# Processing file ipab20120308.txt
# Processing file ipab20120719.txt
# Processing file ipab20120531.txt
# Processing file ipab20120726.txt
# Processing file ipab20120524.txt
# Processing file ipab20120322.txt
# Processing file ipab20121206.txt
# Processing file ipab20121004.txt
# Processing file ipab20121011.txt
# Processing file ipab20121213.txt
# Processing file ipab20120119.txt
# Processing file ipab20120906.txt
# Processing file ipab20120913.txt
# Processing file ipab20120126.txt
# Processing file ipab20120419.txt
# Processing file ipab20121101.txt
# Processing file ipab20121115.txt
# Processing file ipab20120223.txt
# Processing file ipab20121129.txt
# Processing file ipab20120426.txt
# Processing file ipab20120209.txt
# Processing file ipab20120816.txt
# Processing file ipab20120802.txt
# Processing file ipab20120621.txt
# Processing file ipab20120809.txt
# Processing file ipab20120202.txt
# Processing file ipab20121108.txt
# Processing file ipab20120216.txt
# Processing file ipab20120405.txt
# Processing file ipab20120607.txt
# Processing file ipab20121122.txt
# Processing file ipab20120412.txt
# Processing file ipab20120823.txt
# Processing file ipab20120614.txt
# Processing file ipab20120628.txt
# Processing file ipab20120830.txt
# Processing file ipab20120329.txt
# Processing file ipab20120315.txt
# Processing file ipab20120301.txt
# Processing file ipab20120705.txt
# Processing file ipab20121220.txt
# Processing file ipab20120510.txt
# Processing file ipab20120712.txt
# Processing file ipab20120920.txt
# Processing file ipab20120105.txt
# Processing file ipab20121227.txt
# Processing file ipab20121025.txt
# Processing file ipab20121018.txt
# Processing file ipab20120112.txt
# Processing file ipab20120927.txt
# Processing file ipab20120517.txt
# Processing file ipab20120503.txt
# Processing year 2013
# Processing file ipab20131205.txt
# Processing file ipab20130912.txt
# Processing file ipab20130523.txt
# Processing file ipab20131010.txt
# Processing file ipab20131212.txt
# Processing file ipab20130124.txt
# Processing file ipab20130905.txt
# Processing file ipab20130509.txt
# Processing file ipab20130131.txt
# Processing file ipab20130530.txt
# Processing file ipab20130718.txt
# Processing file ipab20130725.txt
# Processing file ipab20131017.txt
# Processing file ipab20131003.txt
# Processing file ipab20130321.txt
# Processing file ipab20131107.txt
# Processing file ipab20130620.txt
# Processing file ipab20130221.txt
# Processing file ipab20130425.txt
# Processing file ipab20130627.txt
# Processing file ipab20131114.txt
# Processing file ipab20131128.txt
# Processing file ipab20130815.txt
# Processing file ipab20130801.txt
# Processing file ipab20130829.txt
# Processing file ipab20130418.txt
# Processing file ipab20130207.txt
# Processing file ipab20130822.txt
# Processing file ipab20130228.txt
# Processing file ipab20130214.txt
# Processing file ipab20130404.txt
# Processing file ipab20130606.txt
# Processing file ipab20131121.txt
# Processing file ipab20130613.txt
# Processing file ipab20130808.txt
# Processing file ipab20130411.txt
# Processing file ipab20130516.txt
# Processing file ipab20130502.txt
# Processing file ipab20130926.txt
# Processing file ipab20131219.txt
# Processing file ipab20131031.txt
# Processing file ipab20130307.txt
# Processing file ipab20130919.txt
# Processing file ipab20130110.txt
# Processing file ipab20131226.txt
# Processing file ipab20131024.txt
# Processing file ipab20130103.txt
# Processing file ipab20130117.txt
# Processing file ipab20130711.txt
# Processing file ipab20130704.txt
# Processing file ipab20130328.txt
# Processing file ipab20130314.txt
# Processing year 2014
# Processing file ipab20140403.txt
# Processing file ipab20140417.txt
# Processing file ipab20141127.txt
# Processing file ipab20140206.txt
# Processing file ipab20140213.txt
# Processing file ipab20141120.txt
# Processing file ipab20140410.txt
# Processing file ipab20140821.txt
# Processing file ipab20140612.txt
# Processing file ipab20140605.txt
# Processing file ipab20141030.txt
# Processing file ipab20140306.txt
# Processing file ipab20140925.txt
# Processing file ipab20140918.txt
# Processing file ipab20140703.txt
# Processing file ipab20140717.txt
# Processing file ipab20140501.txt
# Processing file ipab20140515.txt
# Processing file ipab20140529.txt
# Processing file ipab20140313.txt
# Processing file ipab20141225.txt
# Processing file ipab20141218.txt
# Processing file ipab20140116.txt
# Processing file ipab20140102.txt
# Processing file ipab20140710.txt
# Processing file ipab20141023.txt
# Processing file ipab20141009.txt
# Processing file ipab20140327.txt
# Processing file ipab20140904.txt
# Processing file ipab20140911.txt
# Processing file ipab20140508.txt
# Processing file ipab20140130.txt
# Processing file ipab20141204.txt
# Processing file ipab20140522.txt
# Processing file ipab20141211.txt
# Processing file ipab20140123.txt
# Processing file ipab20140731.txt
# Processing file ipab20140724.txt
# Processing file ipab20141002.txt
# Processing file ipab20141016.txt
# Processing file ipab20140320.txt
# Processing file ipab20140109.txt
# Processing file ipab20140807.txt
# Processing file ipab20141106.txt
# Processing file ipab20141113.txt
# Processing file ipab20140227.txt
# Processing file ipab20140626.txt
# Processing file ipab20140424.txt
# Processing file ipab20140814.txt
# Processing file ipab20140828.txt
# Processing file ipab20140619.txt
# Processing file ipab20140220.txt
# Processing year 2015
# Processing file ipab20150604.txt
# Processing file ipab20150611.txt
# Processing file ipab20150820.txt
# Processing file ipab20150212.txt
# Processing file ipab20151119.txt
# Processing file ipab20150205.txt
# Processing file ipab20151126.txt
# Processing file ipab20150827.txt
# Processing file ipab20150402.txt
# Processing file ipab20150416.txt
# Processing file ipab20150129.txt
# Processing file ipab20150115.txt
# Processing file ipab20150101.txt
# Processing file ipab20151008.txt
# Processing file ipab20151022.txt
# Processing file ipab20150507.txt
# Processing file ipab20150305.txt
# Processing file ipab20151231.txt
# Processing file ipab20151224.txt
# Processing file ipab20150312.txt
# Processing file ipab20150702.txt
# Processing file ipab20150716.txt
# Processing file ipab20150514.txt
# Processing file ipab20150528.txt
# Processing file ipab20150924.txt
# Processing file ipab20150108.txt
# Processing file ipab20151203.txt
# Processing file ipab20151217.txt
# Processing file ipab20151029.txt
# Processing file ipab20151001.txt
# Processing file ipab20151015.txt
# Processing file ipab20150903.txt
# Processing file ipab20150917.txt
# Processing file ipab20150730.txt
# Processing file ipab20150122.txt
# Processing file ipab20151210.txt
# Processing file ipab20150709.txt
# Processing file ipab20150319.txt
# Processing file ipab20150723.txt
# Processing file ipab20150910.txt
# Processing file ipab20150521.txt
# Processing file ipab20150326.txt
# Processing file ipab20150625.txt
# Processing file ipab20150618.txt
# Processing file ipab20150430.txt
# Processing file ipab20150409.txt
# Processing file ipab20151105.txt
# Processing file ipab20150226.txt
# Processing file ipab20150813.txt
# Processing file ipab20151112.txt
# Processing file ipab20150219.txt
# Processing file ipab20150806.txt
# Processing file ipab20150423.txt
# Processing year 2016
# Processing file ipab20160512.txt
# Processing file ipab20161208.txt
# Processing file ipab20160922.txt
# Processing file ipab20160505.txt
# Processing file ipab20160908.txt
# Processing file ipab20160707.txt
# Processing file ipab20160317.txt
# Processing file ipab20160303.txt
# Processing file ipab20161020.txt
# Processing file ipab20160114.txt
# Processing file ipab20161222.txt
# Processing file ipab20160128.txt
# Processing file ipab20160107.txt
# Processing file ipab20161027.txt
# Processing file ipab20160310.txt
# Processing file ipab20160728.txt
# Processing file ipab20160714.txt
# Processing file ipab20160407.txt
# Processing file ipab20160211.txt
# Processing file ipab20160204.txt
# Processing file ipab20161124.txt
# Processing file ipab20160825.txt
# Processing file ipab20160602.txt
# Processing file ipab20160616.txt
# Processing file ipab20160414.txt
# Processing file ipab20160428.txt
# Processing file ipab20160818.txt
# Processing file ipab20161103.txt
# Processing file ipab20161117.txt
# Processing file ipab20160630.txt
# Processing file ipab20160218.txt
# Processing file ipab20160609.txt
# Processing file ipab20160225.txt
# Processing file ipab20160804.txt
# Processing file ipab20160623.txt
# Processing file ipab20160421.txt
# Processing file ipab20160811.txt
# Processing file ipab20161110.txt
# Processing file ipab20161201.txt
# Processing file ipab20161215.txt
# Processing file ipab20161229.txt
# Processing file ipab20160526.txt
# Processing file ipab20160901.txt
# Processing file ipab20160915.txt
# Processing file ipab20160929.txt
# Processing file ipab20160121.txt
# Processing file ipab20160519.txt
# Processing file ipab20160324.txt
# Processing file ipab20161006.txt
# Processing file ipab20161013.txt
# Processing file ipab20160331.txt
# Processing file ipab20160721.txt
# Processing year 2017
# Processing file ipab20170112.txt
# Processing file ipab20171026.txt
# Processing file ipab20170105.txt
# Processing file ipab20171019.txt
# Processing file ipab20170713.txt
# Processing file ipab20170511.txt
# Processing file ipab20170316.txt
# Processing file ipab20170302.txt
# Processing file ipab20170504.txt
# Processing file ipab20170706.txt
# Processing file ipab20170921.txt
# Processing file ipab20171221.txt
# Processing file ipab20171130.txt
# Processing file ipab20170831.txt
# Processing file ipab20170824.txt
# Processing file ipab20170629.txt
# Processing file ipab20170601.txt
# Processing file ipab20170615.txt
# Processing file ipab20170406.txt
# Processing file ipab20170413.txt
# Processing file ipab20171123.txt
# Processing file ipab20171109.txt
# Processing file ipab20170216.txt
# Processing file ipab20170202.txt
# Processing file ipab20170810.txt
# Processing file ipab20170622.txt
# Processing file ipab20170420.txt
# Processing file ipab20170608.txt
# Processing file ipab20170209.txt
# Processing file ipab20170427.txt
# Processing file ipab20170817.txt
# Processing file ipab20170803.txt
# Processing file ipab20171102.txt
# Processing file ipab20171116.txt
# Processing file ipab20170223.txt
# Processing file ipab20170907.txt
# Processing file ipab20170720.txt
# Processing file ipab20171012.txt
# Processing file ipab20170330.txt
# Processing file ipab20170126.txt
# Processing file ipab20171005.txt
# Processing file ipab20170119.txt
# Processing file ipab20171207.txt
# Processing file ipab20170518.txt
# Processing file ipab20170323.txt
# Processing file ipab20170525.txt
# Processing file ipab20170727.txt
# Processing file ipab20170914.txt
# Processing file ipab20170928.txt
# Processing file ipab20170309.txt
# Processing file ipab20171214.txt
# Processing file ipab20171228.txt
# Processing year 2018
# Processing file ipab20180419.txt
# Processing file ipab20181115.txt
# Processing file ipab20181101.txt
# Processing file ipab20181129.txt
# Processing file ipab20180222.txt
# Processing file ipab20180426.txt
# Processing file ipab20180208.txt
# Processing file ipab20180802.txt
# Processing file ipab20180816.txt
# Processing file ipab20180621.txt
# Processing file ipab20180308.txt
# Processing file ipab20180719.txt
# Processing file ipab20180531.txt
# Processing file ipab20180524.txt
# Processing file ipab20180726.txt
# Processing file ipab20180322.txt
# Processing file ipab20181004.txt
# Processing file ipab20181206.txt
# Processing file ipab20180118.txt
# Processing file ipab20181213.txt
# Processing file ipab20180125.txt
# Processing file ipab20181011.txt
# Processing file ipab20180906.txt
# Processing file ipab20180913.txt
# Processing file ipab20180329.txt
# Processing file ipab20180301.txt
# Processing file ipab20180315.txt
# Processing file ipab20180705.txt
# Processing file ipab20181220.txt
# Processing file ipab20180712.txt
# Processing file ipab20180510.txt
# Processing file ipab20180920.txt
# Processing file ipab20181025.txt
# Processing file ipab20180111.txt
# Processing file ipab20181227.txt
# Processing file ipab20180104.txt
# Processing file ipab20181018.txt
# Processing file ipab20180927.txt
# Processing file ipab20180503.txt
# Processing file ipab20180517.txt
# Processing file ipab20180809.txt
# Processing file ipab20181108.txt
# Processing file ipab20180607.txt
# Processing file ipab20180405.txt
# Processing file ipab20180201.txt
# Processing file ipab20180215.txt
# Processing file ipab20181122.txt
# Processing file ipab20180823.txt
# Processing file ipab20180412.txt
# Processing file ipab20180614.txt
# Processing file ipab20180628.txt
# Processing file ipab20180830.txt
# Processing year 2019
# Processing file ipab20190801_2.txt
# Processing file ipab20191107.txt
# Processing file ipab20190620.txt
# Processing file ipab20190221.txt
# Processing file ipab20190627.txt
# Processing file ipab20190425.txt
# Processing file ipab20191114.txt
# Processing file ipab20191128.txt
# Processing file ipab20190418.txt
# Processing file ipab20190801.txt
# Processing file ipab20190815.txt
# Processing file ipab20190829.txt
# Processing file ipab20191205.txt
# Processing file ipab20190523.txt
# Processing file ipab20190912.txt
# Processing file ipab20191212.txt
# Processing file ipab20190124.txt
# Processing file ipab20191010.txt
# Processing file ipab20190905.txt
# Processing file ipab20190509.txt
# Processing file ipab20190131.txt
# Processing file ipab20190530.txt
# Processing file ipab20190822_2.txt
# Processing file ipab20190718.txt
# Processing file ipab20190725.txt
# Processing file ipab20190822_3.txt
# Processing file ipab20191003.txt
# Processing file ipab20191017.txt
# Processing file ipab20190321.txt
# Processing file ipab20190502.txt
# Processing file ipab20190516.txt
# Processing file ipab20190926.txt
# Processing file ipab20191219.txt
# Processing file ipab20191031.txt
# Processing file ipab20190307.txt
# Processing file ipab20190919.txt
# Processing file ipab20190808_2.txt
# Processing file ipab20191024.txt
# Processing file ipab20190110.txt
# Processing file ipab20191226.txt
# Processing file ipab20190815_3.txt
# Processing file ipab20190815_2.txt
# Processing file ipab20190117.txt
# Processing file ipab20190103.txt
# Processing file ipab20190711.txt
# Processing file ipab20190704.txt
# Processing file ipab20190328.txt
# Processing file ipab20190314.txt
# Processing file ipab20190207.txt
# Processing file ipab20190822.txt
# Processing file ipab20190228.txt
# Processing file ipab20190214.txt
# Processing file ipab20190606.txt
# Processing file ipab20190404.txt
# Processing file ipab20191121.txt
# Processing file ipab20190411.txt
# Processing file ipab20190808.txt
# Processing file ipab20190613.txt
# Processing year 2020
# Processing file ipab20200507.txt
# Processing file ipab20200116.txt
# Processing file ipab20200102.txt
# Processing file ipab20200305.txt
# Processing file ipab20200312.txt
# Processing file ipab20200716.txt
# Processing file ipab20200702.txt
# Processing file ipab20200514.txt
# Processing file ipab20200528.txt
# Processing file ipab20200611.txt
# Processing file ipab20200604.txt
# Processing file ipab20200213.txt
# Processing file ipab20200206.txt
# Processing file ipab20200416.txt
# Processing file ipab20200402.txt
# Processing file ipab20200220.txt
# Processing file ipab20200618.txt
# Processing file ipab20200625.txt
# Processing file ipab20200430.txt
# Processing file ipab20200409.txt
# Processing file ipab20200227.txt
# Processing file ipab20200806.txt
# Processing file ipab20200423.txt
# Processing file ipab20200813.txt
# Processing file ipab20200109.txt
# Processing file ipab20200730.txt
# Processing file ipab20200123.txt
# Processing file ipab20200319.txt
# Processing file ipab20200130.txt
# Processing file ipab20200326.txt
# Processing file ipab20200723.txt
# Processing file ipab20200521.txt

# %%
#Files for 2002-2004 have a bit different XML version and require a different parsing code:

for j in range(2002,2005):
    print("Processing year {}".format(j))
    
    directory = '/Users/yulia_zhestkova/Patent parsing/'+str(j)+'/'
    os.chdir('/Users/yulia_zhestkova/Patent parsing/'+str(j)+'/')

#Going through all the txt files and splitting them into individual patent txt pieces
    i=0
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            file=open(file=filename, mode='r')
            file_content_raw=file.read()
            file.close()
            text1=re.compile("<\?xml version=\"1\.0\" encoding\=\"UTF\-8\"\?>")
            file_content=text1.split(file_content_raw)
            while '' in file_content:
                file_content.remove('')
    
            print("Processing file {}".format(filename)) 
            df=pd.DataFrame(file_content, columns=['application_full'])
            df['application_full'].replace(to_replace=r'\n', value='', regex=True, inplace=True)
            df['application_full'].replace(to_replace=r'\"', value='', regex=True, inplace=True)
            df['date_published']=df['application_full'].apply(lambda x: re.search(r'<document-date>(.*)</document-date>', x).group(1))
            df['info']=df['application_full'].apply(lambda x: re.search(r'<domestic-filing-data>(.*)</domestic-filing-data>', x).group(1))
            df['title']=df['application_full'].apply(lambda x: "" if re.search(r'<title-of-invention>(.*)</title-of-invention>', x)==None else re.search(r'<title-of-invention>(.*)</title-of-invention>', x).group(1))
            df['abstract']=df['application_full'].apply(lambda x: "" if re.search('<subdoc-abstract>(.*)</subdoc-abstract>', x)==None else re.search('<subdoc-abstract>(.*)</subdoc-abstract>', x).group(1))
            df['assignee']=df['application_full'].apply(lambda x: "" if re.search('<organization-name>(.*)</organization-name>', x)==None else re.search('<organization-name>(.*)</organization-name>', x).group(1))
            df=df.drop(['application_full'], axis=1)
            df['app_id']=df['info'].apply(lambda x: "" if re.search(r'<doc-number>(.*)</doc-number>', x)==None else re.search(r'<doc-number>(.*)</doc-number>', x).group(1))
            df['date']=df['info'].apply(lambda x: "" if re.search(r'<filing-date>(.*)</filing-date>', x)==None else re.search(r'<filing-date>(.*)</filing-date>', x).group(1))
            df['abstract']=df['abstract'].apply(lambda x: "" if re.search(r'<paragraph id="A-0001" lvl="0">(.*)</paragraph>', x)==None else re.search(r'<paragraph id="A-0001" lvl="0">(.*)</paragraph>', x).group(1))
            df=df[['title', 'abstract', 'assignee', 'app_id', 'date', 'date_published']]
            df['date_published']=df['date_published'].str[:8]
            df['assignee_clean']=df['assignee'].apply(lambda x: "" if re.search(r'>(.*)</organization-name>', x)==None else re.search(r'>(.*)</organization-name>', x).group(1))
            df['assignee_clean']=np.where(df['assignee_clean']!="", df['assignee_clean'], df['assignee'])
            df['assignee_clean'].replace(to_replace=r'>', value='', regex=True, inplace=True)
            df['assignee_clean_final']=df['assignee_clean'].apply(lambda x: "" if re.search('(.*?)</organization-name', x)==None else re.search('(.*?)</organization-name', x).group(1))
            df['assignee_clean_final']=np.where(df['assignee_clean_final']=="", df['assignee_clean'], df['assignee_clean_final'])
            df=df.drop(['assignee', 'assignee_clean'], axis=1)
            df['series_code']=df['app_id'].astype(str).str[:2]
            df['series_id']=df['app_id'].astype(str).str[2:]
            df['text']=df['abstract'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
            df['text']=df['title']+" "+df['abstract']
            df['text']=df['text'].str.lower()
            df['text']=df['text'].apply(lambda x: re.sub(r'[^A-Za-z ]+', '', x))
            df=df.rename(columns={'assignee_clean_final':'assignee'})
            df['assignee']=df['assignee'].str.lower()
            df['assignee'] = df['assignee'].str.replace('&amp',' ')
            df['assignee'] = df['assignee'].str.replace('&apos',' ')
            df['assignee'] = df['assignee'].str.replace('&#x26',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf8',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc4',' ')
            df['assignee'] = df['assignee'].str.replace('&#xdc',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc9',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe9',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe0',' ')
            df['assignee'] = df['assignee'].str.replace('&#xcd',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc0',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc1',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc8',' ')  
            df['assignee'] = df['assignee'].str.replace('&#xd6',' ')           
            df['assignee'] = df['assignee'].str.replace('&#xe7',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xda',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf6',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc2',' ')
            df['assignee'] = df['assignee'].str.replace('&#xd4',' ')  
            df['assignee'] = df['assignee'].str.replace('&#xed',' ')
            df['assignee'] = df['assignee'].str.replace('&#xfc',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc7',' ')
            df['assignee'] = df['assignee'].str.replace('&#xc3',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe8',' ')
            df['assignee'] = df['assignee'].str.replace('&#xe4',' ')
            df['assignee'] = df['assignee'].str.replace('&#xed',' ')
            df['assignee'] = df['assignee'].str.replace('&#xf2',' ')          
            df['assignee'] = df['assignee'].str.replace(' ltd',' ')
            df['assignee'] = df['assignee'].str.replace(' incorporated',' ')
            df['assignee'] = df['assignee'].str.replace(' inc.',' ')
            df['assignee'] = df['assignee'].str.replace(' gmbh',' ')
            df['assignee'] = df['assignee'].str.replace(' ag.',' ')
            df['assignee'] = df['assignee'].str.replace(' kg.',' ')
            df['assignee'] = df['assignee'].str.replace(' llc',' ')
            df['assignee'] = df['assignee'].str.replace(' limited',' ')
            df['assignee'] = df['assignee'].str.replace('s.p.a.',' ')
            df['assignee'] = df['assignee'].str.replace(' corporation',' ')
            df['assignee'] = df['assignee'].str.replace(' group',' ')
            df['assignee'] = df['assignee'].str.replace(' corp.',' ')
            df['assignee'] = df['assignee'].str.replace(' co.',' ')
            df['assignee'] = df['assignee'].str.replace('co. kg',' ')
            df['assignee'] = df['assignee'].str.replace('(publ)',' ')
            df['assignee'] = df['assignee'].str.replace('s.a.s.',' ')
            df['assignee'] = df['assignee'].str.replace('s.r.o.',' ')       
            df['assignee'] = df['assignee'].str.replace('s.r.l.',' ')
            df['assignee'] = df['assignee'].str.replace('k.k.',' ')
            df['assignee'] = df['assignee'].str.replace('b.v.',' ')
            df['assignee'] = df['assignee'].str.replace('s.a.r.l.',' ')
            df['assignee'] = df['assignee'].str.replace('a.s.',' ')
            df['assignee'] = df['assignee'].str.replace('v.v.i.',' ')
            df['assignee'] = df['assignee'].str.replace(' company',' ')
            df=df[['date_published','assignee','text', 'title', 'date', 'series_code', 'series_id', 'app_id']]

            if i==0:
                master_df=df
            else:
                master_df=master_df.append(df, ignore_index=True)
    
            i=i+1
            del df
        
    master_df.to_csv(r'complete'+str(j)+'.csv', index = None)
# Out:
# Processing year 2002
# Processing file pab20020620.txt
# Processing file pab20021107.txt
# Processing file pab20020418.txt
# Processing file pab20020801.txt
# Processing file pab20020815.txt
# Processing file pab20020829.txt
# Processing file pab20021114.txt
# Processing file pab20021128.txt
# Processing file pab20020627.txt
# Processing file pab20020425.txt
# Processing file pab20020221.txt
# Processing file pab20020131.txt
# Processing file pab20020509.txt
# Processing file pab20020905.txt
# Processing file pab20021212.txt
# Processing file pab20020124.txt
# Processing file pab20021010.txt
# Processing file pab20020523.txt
# Processing file pab20020912.txt
# Processing file pab20021205.txt
# Processing file pab20021003.txt
# Processing file pab20021017.txt
# Processing file pab20020321.txt
# Processing file pab20020725.txt
# Processing file pab20020718.txt
# Processing file pab20020530.txt
# Processing file pab20021024.txt
# Processing file pab20020110.txt
# Processing file pab20021226.txt
# Processing file pab20020919.txt
# Processing file pab20021031.txt
# Processing file pab20020307.txt
# Processing file pab20021219.txt
# Processing file pab20020926.txt
# Processing file pab20020502.txt
# Processing file pab20020516.txt
# Processing file pab20020328.txt
# Processing file pab20020314.txt
# Processing file pab20020704.txt
# Processing file pab20020711.txt
# Processing file pab20020117.txt
# Processing file pab20020103.txt
# Processing file pab20020207.txt
# Processing file pab20020411.txt
# Processing file pab20020613.txt
# Processing file pab20020808.txt
# Processing file pab20021121.txt
# Processing file pab20020606.txt
# Processing file pab20020404.txt
# Processing file pab20020228.txt
# Processing file pab20020214.txt
# Processing file pab20020822.txt
# Processing year 2003
# Processing file pab20030619.txt
# Processing file pab20030220.txt
# Processing file pab20030626.txt
# Processing file pab20030424.txt
# Processing file pab20030814.txt
# Processing file pab20030828.txt
# Processing file pab20030227.txt
# Processing file pab20030807.txt
# Processing file pab20031106.txt
# Processing file pab20031113.txt
# Processing file pab20030109.txt
# Processing file pab20030123.txt
# Processing file pab20030731.txt
# Processing file pab20030724.txt
# Processing file pab20031002.txt
# Processing file pab20031016.txt
# Processing file pab20030320.txt
# Processing file pab20031204.txt
# Processing file pab20030522.txt
# Processing file pab20031211.txt
# Processing file pab20030327.txt
# Processing file pab20030904.txt
# Processing file pab20030911.txt
# Processing file pab20030508.txt
# Processing file pab20030130.txt
# Processing file pab20031009.txt
# Processing file pab20030116.txt
# Processing file pab20030102.txt
# Processing file pab20030710.txt
# Processing file pab20031023.txt
# Processing file pab20031225.txt
# Processing file pab20031218.txt
# Processing file pab20031030.txt
# Processing file pab20030306.txt
# Processing file pab20030925.txt
# Processing file pab20030918.txt
# Processing file pab20030703.txt
# Processing file pab20030717.txt
# Processing file pab20030501.txt
# Processing file pab20030515.txt
# Processing file pab20030529.txt
# Processing file pab20030313.txt
# Processing file pab20030605.txt
# Processing file pab20031120.txt
# Processing file pab20030410.txt
# Processing file pab20030821.txt
# Processing file pab20030612.txt
# Processing file pab20030206.txt
# Processing file pab20030213.txt
# Processing file pab20030403.txt
# Processing file pab20030417.txt
# Processing file pab20031127.txt
# Processing year 2004
# Processing file pab20041209.txt
# Processing file pab20040513.txt
# Processing file pab20040506.txt
# Processing file pab20040923.txt
# Processing file pab20040909.txt
# Processing file pab20041223.txt
# Processing file pab20040129.txt
# Processing file pab20040115.txt
# Processing file pab20041021.txt
# Processing file pab20040930.txt
# Processing file pab20040304.txt
# Processing file pab20041230.txt
# Processing file pab20040701.txt
# Processing file pab20040715.txt
# Processing file pab20040729.txt
# Processing file pab20040311.txt
# Processing file pab20040610.txt
# Processing file pab20040205.txt
# Processing file pab20040826.txt
# Processing file pab20040429.txt
# Processing file pab20040401.txt
# Processing file pab20040415.txt
# Processing file pab20040603.txt
# Processing file pab20040617.txt
# Processing file pab20041125.txt
# Processing file pab20041118.txt
# Processing file pab20040212.txt
# Processing file pab20040819.txt
# Processing file pab20040624.txt
# Processing file pab20040812.txt
# Processing file pab20040219.txt
# Processing file pab20040422.txt
# Processing file pab20040408.txt
# Processing file pab20040805.txt
# Processing file pab20041104.txt
# Processing file pab20040226.txt
# Processing file pab20041111.txt
# Processing file pab20040122.txt
# Processing file pab20040527.txt
# Processing file pab20040902.txt
# Processing file pab20040916.txt
# Processing file pab20041202.txt
# Processing file pab20041216.txt
# Processing file pab20040108.txt
# Processing file pab20041014.txt
# Processing file pab20041028.txt
# Processing file pab20040722.txt
# Processing file pab20040520.txt
# Processing file pab20041007.txt
# Processing file pab20040325.txt
# Processing file pab20040708.txt
# Processing file pab20040318.txt

# %%
#Loading a dictionary of words associated with working from home
wfh=['telecommuting', 'telework', 'teleworking', 'working from home', 'mobile work', 'remote work', 'flexible workplace', 'work from home', 'mobile working', 'remote working', 'work remotely', 'working remotely', 'remote workplace', 'telecommuter', 'teleworker', 'home-sourced worker', 'home-sourced employee', 'work-at-home', 'work at home', 'telecommuting specialist', 'nomadic worker', 'nomadic employee', 'work-from-home', 'work-from-anywhere', 'video conference', 'video conferencing', 'virtual office', 'distance work', 'flexible work', 'virtual work', 'virtual office', 'virtual employee', 'home office', 'home-based office', 'home-based work', 'work from anywhere', 'working from anywhere', 'work-from-anywhere', 'digital workplace', 'video chat', 'video call', 'teleconference', 'teleconferencing', 'working from a remote location', 'work from a remote location']

#Redefining files directory
directory = '/Users/yulia_zhestkova/Patent parsing/'
os.chdir('/Users/yulia_zhestkova/Patent parsing/')

#Processing complete csv files (output of the previous code) 
for j in range(2010,2021):
    print("Processing file {}".format(j))
    
    df = pd.read_csv(str(j)+'/complete'+str(j)+'.csv')
#Looking for the word combinations from the dictionary and replacing them with WFH flag 
    df['text']=df['text'].replace({w: "wfhflag" for w in wfh}, regex=True)
#Count how many times WFH flag occurs in a patent abstract and title
    df['count flags']=df['text'].str.count("wfhflag")
    df=df[['date', 'app_id', 'count flags', 'assignee', 'date_published']]
    
    if j==2010:
        df_master=df
    else:
        df_master=df_master.append(df, ignore_index=True)
        
df_master.to_csv (r'wfhflag.csv', index = None)
# Out:
# Processing file 2010
# Processing file 2011
# Processing file 2012
# Processing file 2013
# Processing file 2014
# Processing file 2015
# Processing file 2016
# Processing file 2017
# Processing file 2018
# Processing file 2019
# Processing file 2020
